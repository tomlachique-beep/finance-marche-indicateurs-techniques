# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("../data/Finance_de_marche.xlsx", sheet_name="BMW")
df.head()
# Out:
#         Date  Dernier   Ouv.  Plus Haut  Plus Bas     Vol. Variation %  \
# 0 2025-02-12    76.63  76.16     77.175     76.16  124,70K      +0.54%
# 1 2025-02-11    76.22  76.80     77.040     75.48  911,78K      -1.06%
# 2 2025-02-10    77.04  76.48     77.480     76.34  704,17K      +0.86%
# 3 2025-02-07    76.38  77.84     78.580     76.12    1,03M      -1.60%
# 4 2025-02-06    77.62  76.28     78.200     75.78    1,21M      +1.70%
#
#    Unnamed: 7  Moyenne des 20 premiers   Moyenne des 40 premiers   ...  \
# 0         NaN                   77.8295                  77.77275  ...
# 1         NaN                   77.8500                  77.81900  ...
# 2         NaN                   77.8380                  77.90550  ...
# 3         NaN                   77.7970                  77.95950  ...
# 4         NaN                   77.7970                  77.98100  ...
#
#    Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32  Ecart type  \
# ...

# %%
plt.plot(df["Date"], df["Dernier"])
plt.title("Évolution du cours BMW")
plt.xlabel("Date")
plt.ylabel("Prix")
plt.show()

# %%
import sys
sys.path.append("../src")

import indicators

df2 = indicators.compute_rsi(df)
df2.tail()
# Out:
#           Date  Dernier   Ouv.  Plus Haut  Plus Bas     Vol. Variation %  \
# 526 2023-01-18    91.43  91.64      92.15     91.13  826,43K      -0.60%
# 527 2023-01-17    91.98  91.99      92.56     90.52    1,22M      +0.15%
# 528 2023-01-16    91.84  91.99      92.22     91.31  481,52K      +0.11%
# 529 2023-01-13    91.74  92.49      92.49     90.73    1,70M      -1.59%
# 530 2023-01-12    93.22  91.95      93.36     91.64    1,55M      +1.57%
#
#      Unnamed: 7  Moyenne des 20 premiers   Moyenne des 40 premiers   ...  \
# 526         NaN                 92.042000                 92.042000  ...
# 527         NaN                 92.195000                 92.195000  ...
# 528         NaN                 92.266667                 92.266667  ...
# 529         NaN                 92.480000                 92.480000  ...
# 530         NaN                 93.220000                 93.220000  ...
#
#      Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32  Ecart type  \
# ...
